# %% [markdown]
# # Kaggle'dan colaba nasıl dataset transferi yapımı

# %%
import os
import matplotlib.pyplot as plt

# %%
# Kendi driveımdaki dosyalara colab üzerinden erişmem için gerekli olan komut mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# python kodu normalde terminal komutlarını çalıştıramaz ancak ! işareti ile bu operasyon mümkün kılınır.
# !pwd
# Out:
# /content

# %%
# Operating system'a diyoruzki kaggle doğrulama kodunu bu adreste ara çünkü oraya kopyalamıştık.
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/Colab Notebooks/Input/kaggle (3).json"

# %%
#Changing the working directory
# %cd "/content/drive/MyDrive/Colab Notebooks/Input"
#Check the present working directory using pwd command
# Out:
# /content/drive/MyDrive/Colab Notebooks/Input

# %%
# Bulunduğumuz çalışma dizinini gösterir
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Input

# %%
# İhtiyacımız olan dataseti kaggle üzerinden linkini alıp indiriyoruz
#!/bin/bash
#!/bin/bash
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ozanalpsardoan/plate-dataset")
# Out:
# ...
# 100%|██████████| 2.90G/2.90G [01:13<00:00, 42.5MB/s]
# Extracting files...

# %%
os.chdir('/content/drive/MyDrive')

# %%
# Unzipping the zip files and deleting the zip files
# rm *.zip çıkarıldıktan sonra zip dosyasının silinmesini sağlıyor
# !unzip *.zip && rm *.zip
# Out:
# Archive:  dataset_plate.zip
#    creating: dataset_plate/
#   inflating: dataset_plate/data.yaml
#    creating: dataset_plate/train/
#    creating: dataset_plate/train/images/
#   inflating: dataset_plate/train/images/1.jpg
#   inflating: dataset_plate/train/images/10.jpg
#   inflating: dataset_plate/train/images/100.jpg
#   inflating: dataset_plate/train/images/1000.jpg
#   inflating: dataset_plate/train/images/1001.jpg
#   inflating: dataset_plate/train/images/1002.jpg
#   inflating: dataset_plate/train/images/1003.jpg
#   inflating: dataset_plate/train/images/1004.jpg
#   inflating: dataset_plate/train/images/1005.jpg
#   inflating: dataset_plate/train/images/1006.jpg
#   inflating: dataset_plate/train/images/1007.jpg
#   inflating: dataset_plate/train/images/1008.jpg
#   inflating: dataset_plate/train/images/1009.jpg
#   inflating: dataset_plate/train/images/101.jpg
#   inflating: dataset_plate/train/images/1010.jpg
#   inflating: dataset_plate/train/images/1011.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/usr/local/lib/python3.11/dist-packages)
# ...
#   Using cached ultralytics-8.3.147-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
# Using cached ultralytics-8.3.147-py3-none-any.whl (1.0 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='/content/drive/MyDrive/dataset_plate/data.yaml' epochs=25 imgsz=800 plots=True
# Out:
# Ultralytics 8.3.147 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cat /content/drive/MyDrive/dataset_plate/data.yaml
# Out:
# train: /content/drive/MyDrive/dataset_plate/images/train
# val: /content/drive/MyDrive/dataset_plate/images/val
#
# nc: 1
# names: ["plate"]

# %%
# !ls /content/drive/MyDrive/dataset_plate/images/train
# !ls /content/drive/MyDrive/dataset_plate/images/val
# Out:
# ls: cannot access '/content/drive/MyDrive/dataset_plate/images/train': No such file or directory
# ls: cannot access '/content/drive/MyDrive/dataset_plate/images/val': No such file or directory

# %%
import shutil

shutil.move('/data.yaml','/content/drive/MyDrive/dataset_plate')
# Out:
# '/content/drive/MyDrive/dataset_plate/data.yaml'
